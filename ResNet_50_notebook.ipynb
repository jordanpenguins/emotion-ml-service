# %%
#Necessary imports
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, ZeroPadding2D,\
     Flatten, BatchNormalization, AveragePooling2D, Dense, Activation, Add
from tensorflow.keras.models import Model
from tensorflow.keras import activations
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# **Reading Data from CSV file**
#
# FER 2013 dataset link : https://www.kaggle.com/deadskull7/fer2013

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open("/content/drive/MyDrive/fer2013/fer2013.csv") as f:
      content = f.readlines()

lines = np.array(content)
num_of_instances = lines.size
print("number of instances: ",num_of_instances)
print("Image size: ",len(lines[1].split(",")[1].split(" ")))
# Out:
# number of instances:  35888
# Image size:  2304

# %% [markdown]
# **Splitting data into training and testing**

# %%
x_train, x_trainlabel, x_test, x_testlabel = [], [], [], []
num_classes = 7

# %%
for i in range(1,num_of_instances):
  emotion, img, usage = lines[i].split(",")
  val = img.split(" ")
  val = [int(i) for i in val if i!='']
  pixels = np.array(val, 'float32')
  emotion = keras.utils.to_categorical(emotion, num_classes)
  if 'Training' in usage or 'PrivateTest' in usage:
    x_trainlabel.append(emotion)
    x_train.append(pixels)
  elif 'PublicTest' in usage:
    x_testlabel.append(emotion)
    x_test.append(pixels)

# %% [markdown]
# **Normalizing the pixel values**

# %%
x_train = np.array(x_train, 'float32')
x_trainlabel = np.array(x_trainlabel, 'float32')
x_test = np.array(x_test, 'float32')
x_testlabel = np.array(x_testlabel, 'float32')
x_test_flattened = [np.argmax(i) for i in x_testlabel]
x_test_flattened = np.array(x_test_flattened)

# %%
x_train /= 255 #normalize inputs between [0, 1]
x_test /= 255

x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_train = x_train.astype('float32')
x_test = x_test.reshape(x_test.shape[0], 48, 48, 1)
x_test = x_test.astype('float32')

# %%
print(num_of_instances, 'total samples')
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 35888 total samples
# 32298 train samples
# 3589 test samples

# %%
print("Shape of train data:" ,x_train.shape)
print(x_trainlabel.shape)
print("Shape of test data:",x_test.shape)
print(x_testlabel.shape)
# Out:
# Shape of train data: (32298, 48, 48, 1)
# (32298, 7)
# Shape of test data: (3589, 48, 48, 1)
# (3589, 7)

# %% [markdown]
# **Performing Data Augumentation**

# %%
##Include Little Data Augmentation
batch_size = 256

train_DataGen = tf.keras.preprocessing.image.ImageDataGenerator(zoom_range=0.2,
                                                                width_shift_range=0.1,
                                                                height_shift_range = 0.1,
                                                                horizontal_flip=True)

train_set_conv = train_DataGen.flow(x_train, x_trainlabel, batch_size=batch_size)

# %%
num_classes = 7 #angry, disgust, fear, happy, sad, surprise, neutral
batch_size = 256
epochs = 160

# %% [markdown]
# **ResNet-50 Architecture**

# %%
def res_identity(x, filters):

    x_skip = x # skip connection
    f1, f2 = filters

    #first block
    x = Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation(activations.relu)(x)

    #second block # bottleneck (but size kept same with padding)
    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation(activations.relu)(x)

    # third block activation used after adding the input
    x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    # x = Activation(activations.relu)(x)

    # add the input
    x = Add()([x, x_skip])
    x = Activation(activations.relu)(x)

    return x

# %%
def res_conv(x, s, filters):
    '''
    here the input size changes, when it goes via conv blocks
    so the skip connection uses a projection (conv layer) matrix
    '''
    x_skip = x
    f1, f2 = filters

    # first block
    x = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x)
    # when s = 2 then it is like downsizing the feature map
    x = BatchNormalization()(x)
    x = Activation(activations.relu)(x)

    # second block
    x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation(activations.relu)(x)

    #third block
    x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)

    # shortcut
    x_skip = Conv2D(f2, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x_skip)
    x_skip = BatchNormalization()(x_skip)

    # add
    x = Add()([x, x_skip])
    x = Activation(activations.relu)(x)

    return x

# %%
### Combine the above functions to build 50 layers resnet.
def resnet50():

    input_im = Input(shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3])) # cifar 10 images size
    x = ZeroPadding2D(padding=(3, 3))(input_im)

    # 1st stage


    x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation(activations.relu)(x)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)

    #2nd stage


    x = res_conv(x, s=1, filters=(64, 256))
    x = res_identity(x, filters=(64, 256))
    x = res_identity(x, filters=(64, 256))

    # 3rd stage

    x = res_conv(x, s=2, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))
    x = res_identity(x, filters=(128, 512))

    # 4th stage

    x = res_conv(x, s=2, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))
    x = res_identity(x, filters=(256, 1024))

    # 5th stage

    x = res_conv(x, s=2, filters=(512, 2048))
    x = res_identity(x, filters=(512, 2048))
    x = res_identity(x, filters=(512, 2048))

    # ends with average pooling and dense connection

    x = AveragePooling2D((2, 2), padding='same')(x)

    x = Flatten()(x)
    x = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(x) #multi-class

    # define the model

    model = Model(inputs=input_im, outputs=x, name='Resnet50')

    return model

# %%
resnet50_model = resnet50()

# %%
resnet50_model.summary()
# Out:
# Model: "Resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d      │ (None, 54, 54, 1) │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 24, 24,    │      3,200 │ zero_padding2d[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 24, 24,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 11, 11,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 11, 11,    │      4,160 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 11, 11,    │     36,928 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 11, 11,    │     16,640 │ activation_2[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 11, 11,    │     16,640 │ max_pooling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      1,024 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 11, 11,    │          0 │ add[0][0]         │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 11, 11,    │     16,448 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 11, 11,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 11, 11,    │     16,640 │ activation_5[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 11, 11,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 11, 11,    │     16,448 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 11, 11,    │     36,928 │ activation_7[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 11, 11,    │     16,640 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 11,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 11, 11,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 11, 11,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 6, 6, 128) │     32,896 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 6, 6, 128) │    147,584 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 6, 6, 512) │     66,048 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 6, 6, 512) │    131,584 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 512) │      2,048 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 512) │      2,048 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 6, 6, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 6, 6, 512) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 6, 6, 128) │     65,664 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 6, 6, 128) │    147,584 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 6, 6, 512) │     66,048 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 512) │      2,048 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 6, 6, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 6, 6, 512) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 6, 6, 128) │     65,664 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 6, 6, 128) │    147,584 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 6, 6, 512) │     66,048 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 512) │      2,048 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 6, 6, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 6, 6, 512) │          0 │ add_5[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 6, 6, 128) │     65,664 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 6, 6, 128) │    147,584 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 128) │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 6, 6, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 6, 6, 512) │     66,048 │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 6, 512) │      2,048 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 6, 6, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 6, 6, 512) │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 3, 3, 256) │    131,328 │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_23[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 3, 3,      │    525,312 │ activation_21[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 3, 3,      │          0 │ add_7[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 3, 3, 256) │    262,400 │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_26[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 3, 3,      │          0 │ add_8[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 3, 3, 256) │    262,400 │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_29[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 3, 3,      │          0 │ add_9[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 3, 3, 256) │    262,400 │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_32[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 3, 3,      │          0 │ add_10[0][0]      │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 3, 3, 256) │    262,400 │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_34[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_35[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 3, 3,      │          0 │ add_11[0][0]      │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 3, 3, 256) │    262,400 │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 3, 3, 256) │    590,080 │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3, 256) │      1,024 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 3, 3, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 3, 3,      │    263,168 │ activation_38[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 3, 3,      │      4,096 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 3, 3,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 3, 3,      │          0 │ add_12[0][0]      │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 2, 2, 512) │    524,800 │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ activation_40[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 2, 2,      │  1,050,624 │ activation_41[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 2, 2,      │  2,099,200 │ activation_39[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 2, 2,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 2, 2,      │          0 │ add_13[0][0]      │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 2, 2, 512) │  1,049,088 │ activation_42[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ activation_43[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 2, 2,      │  1,050,624 │ activation_44[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 2, 2,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ activation_42[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 2, 2,      │          0 │ add_14[0][0]      │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 2, 2, 512) │  1,049,088 │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ activation_46[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 2, 2,      │  1,050,624 │ activation_47[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 2, 2,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 2, 2,      │          0 │ add_15[0][0]      │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 1, 1,      │          0 │ activation_48[0]… │
# │ (AveragePooling2D)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 7)         │     14,343 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,595,783 (90.01 MB)
#  Trainable params: 23,542,663 (89.81 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
resnet50_model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=1e-3),
                       metrics=['acc'])

# %%
def lrdecay(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('lr: ', lr)
    return lr
lrdecay = tf.keras.callbacks.LearningRateScheduler(lrdecay) # learning rate decay


def earlystop(mode):
  if mode=='acc':
    estop = tf.keras.callbacks.EarlyStopping(monitor='val_acc', patience=15, mode='max')
  elif mode=='loss':
    estop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, mode='min')
  return estop

# %%
batch_size=batch_size
resnet_train = resnet50_model.fit(train_set_conv,
                                  epochs=160,
                                  steps_per_epoch=x_train.shape[0]//batch_size,
                                  callbacks=[lrdecay])
# Out:
# lr:  0.001
# Epoch 1/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 109s 369ms/step - acc: 0.2290 - loss: 19.5688 - learning_rate: 0.0010
# lr:  0.001
# Epoch 2/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 109us/step - acc: 0.3555 - loss: 13.0266 - learning_rate: 0.0010
# lr:  0.001
# Epoch 3/160
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.3399 - loss: 11.6814 - learning_rate: 0.0010
# lr:  0.001
# Epoch 4/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - acc: 0.3477 - loss: 8.2282 - learning_rate: 0.0010
# lr:  0.001
# Epoch 5/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.3617 - loss: 7.4821 - learning_rate: 0.0010
# lr:  0.001
# Epoch 6/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 99us/step - acc: 0.3398 - loss: 6.0316 - learning_rate: 0.0010
# lr:  0.001
# Epoch 7/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.3772 - loss: 5.5193 - learning_rate: 0.0010
# lr:  0.001
# Epoch 8/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - acc: 0.4570 - loss: 4.6582 - learning_rate: 0.0010
# lr:  0.001
# Epoch 9/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - acc: 0.3770 - loss: 4.7319 - learning_rate: 0.0010
# lr:  0.001
# Epoch 10/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step - acc: 0.2578 - loss: 4.9326 - learning_rate: 0.0010
# lr:  0.001
# Epoch 11/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.3094 - loss: 4.7744 - learning_rate: 0.0010
# lr:  0.001
# Epoch 12/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 94us/step - acc: 0.3594 - loss: 4.1801 - learning_rate: 0.0010
# lr:  0.001
# Epoch 13/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.3806 - loss: 3.9570 - learning_rate: 0.0010
# lr:  0.001
# Epoch 14/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.3867 - loss: 3.4839 - learning_rate: 0.0010
# lr:  0.001
# Epoch 15/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.4063 - loss: 3.4723 - learning_rate: 0.0010
# lr:  0.001
# Epoch 16/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 95us/step - acc: 0.4023 - loss: 3.1741 - learning_rate: 0.0010
# lr:  0.001
# Epoch 17/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - acc: 0.4312 - loss: 3.0774 - learning_rate: 0.0010
# lr:  0.001
# Epoch 18/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step - acc: 0.4375 - loss: 2.9674 - learning_rate: 0.0010
# lr:  0.001
# Epoch 19/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 154ms/step - acc: 0.4270 - loss: 2.9798 - learning_rate: 0.0010
# lr:  0.001
# Epoch 20/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - acc: 0.4414 - loss: 2.7040 - learning_rate: 0.0010
# lr:  0.001
# Epoch 21/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.4606 - loss: 2.6869 - learning_rate: 0.0010
# lr:  0.001
# Epoch 22/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - acc: 0.4688 - loss: 2.5814 - learning_rate: 0.0010
# lr:  0.001
# Epoch 23/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.4420 - loss: 2.5697 - learning_rate: 0.0010
# lr:  0.001
# Epoch 24/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 94us/step - acc: 0.2930 - loss: 3.1477 - learning_rate: 0.0010
# lr:  0.001
# Epoch 25/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.3086 - loss: 3.0226 - learning_rate: 0.0010
# lr:  0.001
# Epoch 26/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159us/step - acc: 0.3359 - loss: 2.7089 - learning_rate: 0.0010
# lr:  0.001
# Epoch 27/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.3826 - loss: 2.6098 - learning_rate: 0.0010
# lr:  0.001
# Epoch 28/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 95us/step - acc: 0.3906 - loss: 2.7294 - learning_rate: 0.0010
# lr:  0.001
# Epoch 29/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.3984 - loss: 2.5715 - learning_rate: 0.0010
# lr:  0.001
# Epoch 30/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 149us/step - acc: 0.4023 - loss: 2.4904 - learning_rate: 0.0010
# lr:  0.001
# Epoch 31/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - acc: 0.4104 - loss: 2.3880 - learning_rate: 0.0010
# lr:  0.001
# Epoch 32/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 95us/step - acc: 0.3789 - loss: 2.5282 - learning_rate: 0.0010
# lr:  0.001
# Epoch 33/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - acc: 0.3868 - loss: 2.5063 - learning_rate: 0.0010
# lr:  0.001
# Epoch 34/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 137us/step - acc: 0.4336 - loss: 2.4048 - learning_rate: 0.0010
# lr:  0.001
# Epoch 35/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.4256 - loss: 2.2715 - learning_rate: 0.0010
# lr:  0.001
# Epoch 36/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - acc: 0.4375 - loss: 2.0799 - learning_rate: 0.0010
# lr:  0.001
# Epoch 37/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.4535 - loss: 2.0830 - learning_rate: 0.0010
# lr:  0.001
# Epoch 38/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - acc: 0.3438 - loss: 2.7767 - learning_rate: 0.0010
# lr:  0.001
# Epoch 39/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - acc: 0.3559 - loss: 2.9026 - learning_rate: 0.0010
# lr:  0.001
# Epoch 40/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - acc: 0.3984 - loss: 2.3596 - learning_rate: 0.0010
# lr:  0.001
# Epoch 41/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.3920 - loss: 2.4278 - learning_rate: 0.0010
# lr:  0.001
# Epoch 42/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - acc: 0.4102 - loss: 2.4896 - learning_rate: 0.0010
# lr:  0.001
# Epoch 43/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.3905 - loss: 2.3604 - learning_rate: 0.0010
# lr:  0.001
# Epoch 44/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 96us/step - acc: 0.4727 - loss: 2.3431 - learning_rate: 0.0010
# lr:  0.001
# Epoch 45/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.4326 - loss: 2.2142 - learning_rate: 0.0010
# lr:  0.001
# Epoch 46/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - acc: 0.4258 - loss: 2.0163 - learning_rate: 0.0010
# lr:  0.001
# Epoch 47/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.4631 - loss: 1.9244 - learning_rate: 0.0010
# lr:  0.001
# Epoch 48/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 109us/step - acc: 0.3711 - loss: 2.1986 - learning_rate: 0.0010
# lr:  0.001
# Epoch 49/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.3681 - loss: 2.4320 - learning_rate: 0.0010
# lr:  0.001
# Epoch 50/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - acc: 0.4258 - loss: 2.2782 - learning_rate: 0.0010
# lr:  0.001
# Epoch 51/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - acc: 0.4256 - loss: 2.1077 - learning_rate: 0.0010
# lr:  0.001
# Epoch 52/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - acc: 0.5000 - loss: 1.8831 - learning_rate: 0.0010
# lr:  0.001
# Epoch 53/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 158ms/step - acc: 0.4566 - loss: 1.8996 - learning_rate: 0.0010
# lr:  0.001
# Epoch 54/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.4414 - loss: 1.8385 - learning_rate: 0.0010
# lr:  0.001
# Epoch 55/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - acc: 0.4638 - loss: 1.9345 - learning_rate: 0.0010
# lr:  0.001
# Epoch 56/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - acc: 0.5039 - loss: 1.9571 - learning_rate: 0.0010
# lr:  0.001
# Epoch 57/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.4780 - loss: 1.8693 - learning_rate: 0.0010
# lr:  0.001
# Epoch 58/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 109us/step - acc: 0.4805 - loss: 1.7087 - learning_rate: 0.0010
# lr:  0.001
# Epoch 59/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.4105 - loss: 2.2772 - learning_rate: 0.0010
# lr:  0.001
# Epoch 60/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 163us/step - acc: 0.2617 - loss: 2.6505 - learning_rate: 0.0010
# lr:  0.001
# Epoch 61/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - acc: 0.3159 - loss: 2.4561 - learning_rate: 0.0010
# lr:  0.001
# Epoch 62/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - acc: 0.4062 - loss: 2.1186 - learning_rate: 0.0010
# lr:  0.001
# Epoch 63/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - acc: 0.4080 - loss: 2.0019 - learning_rate: 0.0010
# lr:  0.001
# Epoch 64/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - acc: 0.4727 - loss: 1.8188 - learning_rate: 0.0010
# lr:  0.001
# Epoch 65/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - acc: 0.4424 - loss: 1.8975 - learning_rate: 0.0010
# lr:  0.001
# Epoch 66/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - acc: 0.4609 - loss: 1.9167 - learning_rate: 0.0010
# lr:  0.001
# Epoch 67/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.4715 - loss: 1.7975 - learning_rate: 0.0010
# lr:  0.001
# Epoch 68/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 116us/step - acc: 0.4727 - loss: 1.6843 - learning_rate: 0.0010
# lr:  0.001
# Epoch 69/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - acc: 0.4750 - loss: 1.6809 - learning_rate: 0.0010
# lr:  0.001
# Epoch 70/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.4297 - loss: 2.1438 - learning_rate: 0.0010
# lr:  0.001
# Epoch 71/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.4512 - loss: 1.9093 - learning_rate: 0.0010
# lr:  0.001
# Epoch 72/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - acc: 0.4297 - loss: 1.7256 - learning_rate: 0.0010
# lr:  0.001
# Epoch 73/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - acc: 0.4939 - loss: 1.6414 - learning_rate: 0.0010
# lr:  0.001
# Epoch 74/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - acc: 0.5508 - loss: 1.5003 - learning_rate: 0.0010
# lr:  0.001
# Epoch 75/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.4855 - loss: 1.7483 - learning_rate: 0.0010
# lr:  0.001
# Epoch 76/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - acc: 0.5078 - loss: 2.1956 - learning_rate: 0.0010
# lr:  0.001
# Epoch 77/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.4722 - loss: 1.9443 - learning_rate: 0.0010
# lr:  0.001
# Epoch 78/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - acc: 0.5352 - loss: 1.6010 - learning_rate: 0.0010
# lr:  0.001
# Epoch 79/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.5039 - loss: 1.6115 - learning_rate: 0.0010
# lr:  0.001
# Epoch 80/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - acc: 0.5078 - loss: 1.6426 - learning_rate: 0.0010
# lr:  0.001
# Epoch 81/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.4931 - loss: 1.6982 - learning_rate: 0.0010
# lr:  0.0001
# Epoch 82/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 123us/step - acc: 0.4219 - loss: 1.8310 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 83/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.4843 - loss: 1.6936 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 84/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - acc: 0.5352 - loss: 1.5240 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 85/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - acc: 0.5103 - loss: 1.5767 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 86/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 133us/step - acc: 0.4883 - loss: 1.5669 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 87/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.5330 - loss: 1.4991 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 88/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.5391 - loss: 1.3921 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 89/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5308 - loss: 1.4726 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 90/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - acc: 0.5469 - loss: 1.4151 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 91/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - acc: 0.5490 - loss: 1.4149 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 92/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - acc: 0.5234 - loss: 1.4148 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 93/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.5517 - loss: 1.3951 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 94/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - acc: 0.5938 - loss: 1.3353 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 95/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5592 - loss: 1.3663 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 96/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.5195 - loss: 1.3628 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 97/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.5638 - loss: 1.3468 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 98/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 153us/step - acc: 0.5547 - loss: 1.3544 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 99/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5659 - loss: 1.3248 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 100/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - acc: 0.5820 - loss: 1.4191 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 101/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5683 - loss: 1.3169 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 102/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 161us/step - acc: 0.5859 - loss: 1.2779 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 103/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5765 - loss: 1.2950 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 104/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - acc: 0.6094 - loss: 1.1802 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 105/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - acc: 0.5798 - loss: 1.2739 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 106/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 171us/step - acc: 0.5195 - loss: 1.3977 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 107/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.5797 - loss: 1.2703 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 108/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - acc: 0.5859 - loss: 1.2983 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 109/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.5878 - loss: 1.2492 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 110/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162us/step - acc: 0.6406 - loss: 1.1402 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 111/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - acc: 0.5879 - loss: 1.2457 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 112/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - acc: 0.5742 - loss: 1.1825 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 113/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.5986 - loss: 1.2281 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 114/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - acc: 0.6094 - loss: 1.2000 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 115/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - acc: 0.5984 - loss: 1.2119 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 116/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - acc: 0.5977 - loss: 1.2495 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 117/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.6015 - loss: 1.2089 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 118/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - acc: 0.6016 - loss: 1.1961 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 119/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - acc: 0.6072 - loss: 1.1933 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 120/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - acc: 0.5508 - loss: 1.3226 - learning_rate: 1.0000e-04
# lr:  0.0001
# Epoch 121/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 40s 156ms/step - acc: 0.5971 - loss: 1.2000 - learning_rate: 1.0000e-04
# lr:  1e-05
# Epoch 122/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - acc: 0.6328 - loss: 1.1502 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 123/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - acc: 0.6202 - loss: 1.1541 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 124/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - acc: 0.6172 - loss: 1.1661 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 125/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - acc: 0.6176 - loss: 1.1489 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 126/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - acc: 0.5977 - loss: 1.2460 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 127/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - acc: 0.6298 - loss: 1.1318 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 128/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 168us/step - acc: 0.5781 - loss: 1.2423 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 129/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - acc: 0.6241 - loss: 1.1356 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 130/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - acc: 0.6406 - loss: 1.0505 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 131/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.6281 - loss: 1.1297 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 132/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 165us/step - acc: 0.6719 - loss: 1.0109 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 133/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 159ms/step - acc: 0.6265 - loss: 1.1268 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 134/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - acc: 0.6055 - loss: 1.1787 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 135/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 19s 153ms/step - acc: 0.6300 - loss: 1.1227 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 136/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 114us/step - acc: 0.6719 - loss: 1.0900 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 137/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.6259 - loss: 1.1268 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 138/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - acc: 0.6289 - loss: 1.1320 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 139/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.6292 - loss: 1.1193 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 140/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - acc: 0.5781 - loss: 1.2420 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 141/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.6311 - loss: 1.1196 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 142/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - acc: 0.6602 - loss: 1.0291 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 143/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.6343 - loss: 1.1115 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 144/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 199us/step - acc: 0.5781 - loss: 1.1611 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 145/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - acc: 0.6358 - loss: 1.1076 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 146/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 117us/step - acc: 0.6953 - loss: 1.0048 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 147/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.6343 - loss: 1.1158 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 148/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 134us/step - acc: 0.5820 - loss: 1.1397 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 149/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - acc: 0.6330 - loss: 1.0991 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 150/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - acc: 0.6406 - loss: 1.1319 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 151/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.6306 - loss: 1.1011 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 152/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 120us/step - acc: 0.7031 - loss: 1.0017 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 153/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.6397 - loss: 1.0960 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 154/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 164us/step - acc: 0.6094 - loss: 1.1167 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 155/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - acc: 0.6367 - loss: 1.0910 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 156/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - acc: 0.6484 - loss: 1.1566 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 157/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - acc: 0.6342 - loss: 1.0938 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 158/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 156us/step - acc: 0.6367 - loss: 1.0887 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 159/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - acc: 0.6372 - loss: 1.0900 - learning_rate: 1.0000e-05
# lr:  1e-05
# Epoch 160/160
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 122us/step - acc: 0.6562 - loss: 1.1050 - learning_rate: 1.0000e-05

# %% [markdown]
# **Accuracy obtained**

# %%
train_score = resnet50_model.evaluate(x_train, x_trainlabel, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy:', 100*train_score[1])

test_score = resnet50_model.evaluate(x_test, x_testlabel, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy:', 100*test_score[1])
# Out:
# Train loss: 1.0304625034332275
# Train accuracy: 66.21152758598328
# Test loss: 1.162333607673645
# Test accuracy: 61.43772602081299

# %% [markdown]
# **Saving and loading the model**

# %%
resnet50_model.save("/content/drive/MyDrive/Colab Notebooks/resnet50_tt_fermod_68.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import load_model
resnet50_model = load_model("/content/drive/MyDrive/Colab Notebooks/resnet50_tt_fermod_68.h5")
trainloss , trainaccuracy = resnet50_model.evaluate(x_train,x_trainlabel)
testloss, testaccuracy = resnet50_model.evaluate(x_test, x_testlabel)
print('Train loss:', trainloss)
print('Train accuracy:', 100*trainaccuracy)
print('Test loss:', testloss)
print('Test accuracy:', 100*testaccuracy)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1010/1010 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - acc: 0.6583 - loss: 1.0385
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - acc: 0.6198 - loss: 1.1507
# Train loss: 1.0304625034332275
# Train accuracy: 66.21152758598328
# Test loss: 1.162333607673645
# Test accuracy: 61.43772602081299

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def classification(predictions):
    class_types = ['angry', 'disgust', 'fear', 'happy', 'sad',
               'surprise', 'neutral']
    print("Classification Report:\n")
    cr=classification_report(x_test_flattened,
                                np.argmax(np.round(predictions), axis=1),
                                target_names=[class_types[i] for i in range(len(class_types))])
    print(cr)

# %%
pred_class_resnet50 = resnet50_model.predict(x_test)

classification(pred_class_resnet50)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        angry       0.24      0.82      0.37       467
#      disgust       0.62      0.23      0.34        56
#         fear       0.59      0.26      0.36       496
#        happy       0.90      0.77      0.83       895
#          sad       0.64      0.26      0.37       653
#     surprise       0.83      0.73      0.78       415
#      neutral       0.66      0.41      0.51       607
#
#     accuracy                           0.54      3589
#    macro avg       0.64      0.50      0.51      3589
# weighted avg       0.67      0.54      0.55      3589

# %%
 class_types = ['angry', 'disgust', 'fear', 'happy', 'sad',
               'surprise', 'neutral']
x_predicted = resnet50_model.predict(x_test)
x_predicted_labels = [np.argmax(i) for i in x_predicted]
cm = tf.math.confusion_matrix(labels=x_test_flattened,predictions=x_predicted_labels)

plt.figure(figsize = (10,7))
sns_hmp = sns.heatmap(cm, annot=True,xticklabels = [class_types[i] for i in range(len(class_types))],
                yticklabels = [class_types[i] for i in range(len(class_types))], fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Expected')
#fig = sns_hmp.get_figure()
#fig.savefig('/content/drive/MyDrive/graphs/confusion_matrix', dpi=250)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Text(95.72222222222221, 0.5, 'Expected')

# %% [markdown]
# **Testing an image**

# %%
def emotion_analysis(emotions):
    objects = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
    y_pos = np.arange(len(objects))

    plt.bar(y_pos, emotions, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')

    plt.show()

# %%
import cv2
import math
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator



d = {0:"angry",1:"disgust",2:"fear",3:"happiness",4:"sad",5:"surprise",6:"neutral"}
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml')


file = '/content/drive/MyDrive/Pictures/image_test1.jpg'
true_image = image.load_img(file)
t_image = cv2.imread(file)
#img = image.load_img(file, grayscale=True, target_size=(48, 48))
gray = cv2.cvtColor(t_image,cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray,1.1,4)

if(len(faces) == 0):
    exit()

for (x,y,w,h) in faces:
    cv2.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),2)
    start_row,end_row,start_col,end_col = y,y+h,x,x+h

croppedimage = gray[start_row:end_row,start_col:end_col]
img = cv2.resize(croppedimage,(48,48))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom = resnet50_model.predict(x)
emotion_analysis(custom[0])
print(custom[0])

emt = list(custom[0])
idx = emt.index(max(emt))
imgname = d[idx]
print(imgname)

x = np.array(x, 'float32')
x = x.reshape([48, 48]);

plt.gray()
plt.imshow(true_image)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [8.4682417e-01 1.9408934e-02 1.1578221e-01 3.8627992e-04 1.3469519e-02
#  3.6909105e-03 4.3804571e-04]
# angry

# %% [markdown]
# **Testing a video sample**

# %%
def getFrame(seconds):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,seconds*1000)
    hasFrames,img = vidcap.read()

    if hasFrames:
        minutes = "00"
        hours = "00"
        if seconds >= 60:
            minutes = str(seconds//60)
            seconds = seconds % 60

        if int(minutes) >= 60:
            hours = str(int(minutes)//60)
            minutes = str(int(minutes) % 60)

        min = "{:02d}".format(int(minutes))
        sec = "{:02d}".format(seconds)
        hrs = "{:02d}".format(int(hours))

        flag = 0
        frameId = vidcap.get(1)
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray,1.1,4)

        if(len(faces)==0):
            flag = 1

        if flag == 0 :
            global count
            count = count + 1
            for (x,y,w,h) in faces:
                cv2.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),2)
                start_row,end_row,start_col,end_col = y,y+h,x,x+h

            croppedimage = gray[start_row:end_row,start_col:end_col]
            finalimg = cv2.resize(croppedimage,(48,48))

            x = image.img_to_array(finalimg)
            x = np.expand_dims(x, axis = 0)

            x /= 255

            custom = resnet50_model.predict(x)
            emt = list(custom[0])
            idx = emt.index(max(emt))
            imgname = d[idx]
            dcount[imgname] = dcount[imgname] + 1

            cv2.imwrite("/content/drive/MyDrive/detection/" + "%d_" % count +imgname+"__"+ hrs+":"+min+":"+sec+".jpg" ,img)

    return hasFrames

# %%
import cv2
import math
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

videoFile = "/content/drive/MyDrive/videosamples/video2.mp4"
vidcap = cv2.VideoCapture(videoFile)

d = {0:"angry",1:"disgust",2:"fear",3:"happiness",4:"sad",5:"surprise",6:"neutral"}
dcount = {"angry":0,"disgust":0,"fear":0,"happiness":0,"sad":0,"surprise":0,"neutral":0}

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt.xml')
count = 0

sec = 0
frameRate = 2 #it will capture image in each 2 second
success = getFrame(sec)
while success:
    sec = sec + frameRate
    #sec = round(sec, 2)
    success = getFrame(sec)

print ("Done!")
print("Extracted images:",count)
print(dcount)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Done!
# Extracted images: 85
# {'angry': 6, 'disgust': 2, 'fear': 8, 'happiness': 16, 'sad': 21, 'surprise': 2, 'neutral': 30}

# %% [markdown]
# **Plotting a bar chart of predicted emotions**

# %%
emotions = list(dcount.keys())
values = list(dcount.values())

fig, ax = plt.subplots()
width = 0.8
ind = np.arange(len(values))

plt.bar(emotions, values, width, color ='blue')

for index, value in enumerate(values):
    ax.text(index - 0.1, value + 0.70, str(value))

plt.xlabel("Emotions")
plt.ylabel("no of times exhibited")
plt.title("Emotional analysis")

plt.savefig('/content/drive/MyDrive/graphs/frequency.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from python-docx) (4.14.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %% [markdown]
# **Creating a summary report**

# %%
from docx import document

# %%
from docx import Document
from docx.shared import Inches
from docx.shared import RGBColor
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH

document = Document()
p1 = document.add_paragraph()
paragraph_format = p1.paragraph_format
paragraph_format.alignment = WD_ALIGN_PARAGRAPH.CENTER
p12 = p1.add_run("REPORT ON EMOTIONS PREDICTED")
f1 = p12.font
f1.size = Pt(16)
f1.underline = True
f1.bold = True

paragraph_format.line_spacing = 1.75

p2 = document.add_paragraph()
p22 = p2.add_run("Name of the video:")
f2 = p22.font
f2.name = 'Calibri'
f2.size = Pt(14)
f2.bold = True
p2.add_run(" video2.mp4").font.size = Pt(13)


p3 = document.add_paragraph()
p32 = p3.add_run("Frames extracted link:")
f3 = p32.font
f3.name = 'Calibri'
f3.size = Pt(14)
f3.bold = True
document.add_paragraph('https://drive.google.com/drive/folders/1yw7eNLjjoUXOa2YMe1fFPNPyBuec45dm?usp=sharing')
document.add_paragraph("(Frames are extracted every 2 seconds)")

p4 = document.add_paragraph()
p42 = p4.add_run("Types of emotions predicted")
f4 = p42.font
f4.name = 'Calibri'
f4.size = Pt(14)
f4.bold = True
document.add_paragraph('Angry', style='List Bullet')
document.add_paragraph('Disgust', style='List Bullet')
document.add_paragraph('Fear', style='List Bullet')
document.add_paragraph('Happy', style='List Bullet')
document.add_paragraph('Sad', style='List Bullet')
document.add_paragraph('Surprise', style='List Bullet')
document.add_paragraph('Neutral', style='List Bullet')

p5 = document.add_paragraph()
p52 = p5.add_run("DETAILED ANALYSIS")
f5 = p52.font
f5.size = Pt(14)
f5.underline = True
f5.bold = True

p = document.add_paragraph()
p.add_run('Frequency graph:').bold = True
p.add_run(" No of times the person exhibited a particular emotion")

print("Report created successfully")

document.add_picture('/content/drive/MyDrive/graphs/frequency.png', width=Inches(5.25))
document.save('/content/drive/MyDrive/graphs/emotion_report.docx')
# Out:
# Report created successfully
